# %% [markdown]
# SIMILAR Q. to prac 1 q.

# %%
def list_of_dicts(marks):
    keys = marks.keys()
    vals = zip(*[marks[k] for k in keys])
    result = [dict(zip(keys, v)) for v in vals]
    return result
marks = {'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}
print("Original dictionary of lists:")
print(marks)
print("\nSplit said dictionary of lists into list of dictionaries:")
print(list_of_dicts(marks))
# Out:
# Original dictionary of lists:
# {'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}
#
# Split said dictionary of lists into list of dictionaries:
# [{'Science': 88, 'Language': 77}, {'Science': 89, 'Language': 78}, {'Science': 62, 'Language': 84}, {'Science': 95, 'Language': 80}]

# %% [markdown]
# # PRACTICAL QUES. 1

# %%
def list_of_dict(heights):
    keys=heights.keys()
    values = zip(*[heights[k] for k in keys]) 
    result = [dict(zip(keys,v )) for v in values]
    return result

heights = {'Boys':[72,68,70,69,74], 'Girls':[63,65,69,62,61]}
print("\n ORIGINAL DICTIONARY OF LISTS ::" , heights)
print("\n NOW LIST OF DICTIONARIES :: \n",list_of_dict(heights))
# Out:
#  ORIGINAL DICTIONARY OF LISTS :: {'Boys': [72, 68, 70, 69, 74], 'Girls': [63, 65, 69, 62, 61]}
#
#  NOW LIST OF DICTIONARIES ::
#  [{'Boys': 72, 'Girls': 63}, {'Boys': 68, 'Girls': 65}, {'Boys': 70, 'Girls': 69}, {'Boys': 69, 'Girls': 62}, {'Boys': 74, 'Girls': 61}]

# %% [markdown]
# # PRACTICAL QUES. 2

# %%
#prac 2 a
import numpy as np
#arr=np.random.randint(1,50,(4,6))
#arr
arr = np.arange(2,10).reshape(2,4)
print("\nORIGINAL ARRAY :: ")
print(arr)
print( "\nMEAN :: ", arr.mean(axis =1))
print("\nSTANDARD DEVIATION :: ",arr.std(axis=1))
print("\nVARIANCE :: ",arr.var(axis=1))
# Out:
# ORIGINAL ARRAY ::
# [[2 3 4 5]
#  [6 7 8 9]]
#
# MEAN ::  [3.5 7.5]
#
# STANDARD DEVIATION ::  [1.11803399 1.11803399]
#
# VARIANCE ::  [1.25 1.25]

# %%
import numpy as np
x = np.arange(2,10).reshape(2,4)
print("\nORIGINAL ARRAY :: ")
print(x)
r1 = np.mean(x)
r2 = np.average(x)
assert np.allclose(r1, r2)
print("\nMEAN :: ", r1)
r1 = np.std(x)
r2 = np.sqrt(np.mean((x - np.mean(x)) ** 2 ))
assert np.allclose(r1, r2)
print("\nSTANDARD DEVIATION :: ", 1)
r1= np.var(x)
r2 = np.mean((x - np.mean(x)) ** 2 )
assert np.allclose(r1, r2)
print("\nVARIANCE :: ", r1)
# Out:
# ORIGINAL ARRAY ::
# [[2 3 4 5]
#  [6 7 8 9]]
#
# MEAN ::  5.5
#
# STANDARD DEVIATION ::  1
#
# VARIANCE ::  5.25

# %%
#prac 2 b
import numpy as np
B = np.array([56,48,22,41,78,91,24,46,8,33])
print("ORIGINAL ARRAY :: ")
print(B)
B_sort = np.sort(B)
B_sort_index = np.argsort(B)
print("SORTED ARRAY :: ")
print(B_sort)
print("Indices of the sorted elements of a given array:")
print(B_sort_index)
# Out:
# ORIGINAL ARRAY ::
# [56 48 22 41 78 91 24 46  8 33]
# SORTED ARRAY ::
# [ 8 22 24 33 41 46 48 56 78 91]
# Indices of the sorted elements of a given array:
# [8 2 6 9 3 7 1 0 4 5]

# %%
#prac 2 c
import numpy as np
x = np.arange(2,10).reshape(2,4)
print("ORIGINAL ARRAY :: ")
print(x)
print("TYPE of the array is :: ",type(x))
print("SHAPE  of the array :: ",x.shape)
print("DTYPE of the array :: ",x.dtype)

y = np.reshape(x,(4,2))
print("RESHAPE ARRAY IS :: \n",y)
# Out:
# ORIGINAL ARRAY ::
# [[2 3 4 5]
#  [6 7 8 9]]
# TYPE of the array is ::  <class 'numpy.ndarray'>
# SHAPE  of the array ::  (2, 4)
# DTYPE of the array ::  int32
# RESHAPE ARRAY IS ::
#  [[2 3]
#  [4 5]
#  [6 7]
#  [8 9]]

# %%
#try prac 2 d
import numpy as np
x = np.array([1, 2, 3, 4])
print("ORIGINAL ARRAY ::--> ",x)
print("\nTest if none of the elements of the said array is zero ::--> ", np.all(x))

res = np.where(x == 0)[0]
print("The index of the  zero elements is :: ",res)

x = np.array([0, 1, 2, 3])
print("\nORIGINAL ARRAY ::--> ",x)
print("\nTest if none of the elements of the said array is zero ::--> ",np.all(x))

res = np.where(x == 0)[0]
print("The index of the  zero elements is :: ",res)


x = np.array([1, 0, 0, 0])
print("\n--------------------\nORIGINAL ARRAY :: ",x)
print("\nTest whether any of the elements of a given array is non-zero ::",np.any(x))
res = np.where(x != 0)[0]
print("The index of the non- zero elements is :: ",res)
x = np.array([0, 0, 0, 0])

print("\nOriginal array ::",x)

print("\nTest whether any of the elements of a given array is non-zero ::",np.any(x))
res = np.where(x != 0)[0]
print("The index of the non-zero elements is :: ",res)


a = np.array([1, 0, np.nan, np.inf])
print("\n--------------------\nORIGINAL ARRAY ::--> ",a)
print("\nTest element-wise for NaN :: ",np.isnan(a))

res = np.where(np.isnan(a) == True)[0]
print("The index of the  zero elements is :: ",res)
# Out:
# ORIGINAL ARRAY ::-->  [1 2 3 4]
#
# Test if none of the elements of the said array is zero ::-->  True
# The index of the  zero elements is ::  []
#
# ORIGINAL ARRAY ::-->  [0 1 2 3]
#
# Test if none of the elements of the said array is zero ::-->  False
# The index of the  zero elements is ::  [0]
#
# --------------------
# ORIGINAL ARRAY ::  [1 0 0 0]
#
# Test whether any of the elements of a given array is non-zero :: True
# The index of the non- zero elements is ::  [0]
#
# Original array :: [0 0 0 0]
#
# Test whether any of the elements of a given array is non-zero :: False
# The index of the non-zero elements is ::  []
#
# --------------------
# ORIGINAL ARRAY ::-->  [ 1.  0. nan inf]
#
# Test element-wise for NaN ::  [False False  True False]
# The index of the  zero elements is ::  [2]

# %%
import numpy as np
arr = np.array([2, np.nan, 6, 8, 9, 10, np.nan])
b = np.isnan(arr) 
print(b)
# Out:
# [False  True False False False False  True]

# %%
#prac 2 d
import numpy as np
x = np.array([1, 2, 3, 4])
print("ORIGINAL ARRAY ::--> ",x)
print("\nTest if none of the elements of the said array is zero ::--> ", np.all(x))

res = np.where(x == 0)[0]
print("The index of the  zero elements is :: ",res)


x = np.array([1, 0, 0, 3, 2, 0])
print("\n-------------------------------------------------------")
print("\nORIGINAL ARRAY ::--> ",x)
print("\nTest whether any of the elements of a given array is non-zero ::",np.any(x))
res = np.where(x != 0)[0]
print("The index of the non- zero elements is :: ",res)
x = np.array([0, 0, 0, 0])


a = np.array([1, 0, np.nan, 3, np.nan])
print("\n-------------------------------------------------------")
print("\nORIGINAL ARRAY ::--> ",a)
print("\nTest element-wise for NaN :: ",np.isnan(a))

res = np.where(np.isnan(a) == True)[0]
print("The index of the  zero elements is :: ",res)
# Out:
# ORIGINAL ARRAY ::-->  [1 2 3 4]
#
# Test if none of the elements of the said array is zero ::-->  True
# The index of the  zero elements is ::  []
#
# -------------------------------------------------------
#
# ORIGINAL ARRAY ::-->  [1 0 0 3 2 0]
#
# Test whether any of the elements of a given array is non-zero :: True
# The index of the non- zero elements is ::  [0 3 4]
#
# -------------------------------------------------------
#
# ORIGINAL ARRAY ::-->  [ 1.  0. nan  3. nan]
#
# Test element-wise for NaN ::  [False False  True False  True]
# The index of the  zero elements is ::  [2 4]

# %% [markdown]
# # PRACTICAL QUES. 3

# %%
import pandas as pd
import numpy as np
import random
dataframe = pd.DataFrame(np.random.randint(0,100,size=(50,3)), columns=list('123'))
dataframe
# Out:
#      1   2   3
# 0   96  54  38
# 1   53   0   4
# 2   62  96  36
# 3   48  84   1
# 4   11  38  77
# 5   87  12  75
# 6   98   3  44
# 7   85  90  57
# 8   84  62  48
# 9   31  95  24
# 10  15  75  51
# 11  91  60  65
# 12  35  55  35
# 13  33  59  68
# 14  39  54  49
# 15  49  39  59
# 16  28  22  68
# 17  69  58  79
# 18  67  56  17
# 19  79  88  63
# 20  91  45  78
# 21  48  52  85
# 22  28  83  91
# 23  18  65  43
# 24  93  39  92
# 25  52  18  42
# 26  78  67  84
# 27  52  33  78
# 28  43   2  31
# 29  54  25   2
# 30  98  64  39
# 31  35  78  63
# 32  69  19  38
# 33  42   5  23
# 34  54  66  80
# 35  55  10  31
# 36  53  85  82
# 37   4  70  97
# 38  50  13  57
# 39  90  68  90
# 40  36  30   4
# 41  55  75  26
# 42  77  99  43
# 43  45  40  65
# 44  20  61  60
# 45  70   5  58
# 46  89  92   8
# 47   9  79   4
# 48   2  65  52
# 49  74  53   7

# %%
#replace the values with null
for c in  dataframe.columns:
    dataframe.loc[dataframe.sample(frac=0.10).index,c]=np.nan
dataframe
# Out:
#        1     2     3
# 0   96.0  54.0  38.0
# 1   53.0   0.0   4.0
# 2    NaN  96.0  36.0
# 3   48.0  84.0   1.0
# 4    NaN   NaN  77.0
# 5   87.0  12.0   NaN
# 6   98.0   3.0  44.0
# 7   85.0  90.0  57.0
# 8    NaN  62.0  48.0
# 9    NaN  95.0  24.0
# 10  15.0  75.0  51.0
# 11  91.0  60.0  65.0
# 12  35.0  55.0  35.0
# 13  33.0  59.0  68.0
# 14  39.0  54.0  49.0
# 15  49.0  39.0  59.0
# 16  28.0  22.0   NaN
# 17  69.0   NaN  79.0
# 18  67.0  56.0  17.0
# 19  79.0  88.0  63.0
# 20  91.0  45.0  78.0
# 21  48.0  52.0  85.0
# 22  28.0  83.0  91.0
# 23  18.0  65.0  43.0
# 24  93.0  39.0  92.0
# 25  52.0  18.0   NaN
# 26  78.0  67.0  84.0
# 27  52.0  33.0  78.0
# 28  43.0   2.0  31.0
# 29  54.0  25.0   2.0
# 30  98.0  64.0  39.0
# 31  35.0  78.0  63.0
# 32  69.0  19.0  38.0
# 33  42.0   NaN  23.0
# 34  54.0  66.0   NaN
# 35  55.0  10.0  31.0
# 36  53.0  85.0  82.0
# 37   4.0  70.0  97.0
# 38  50.0  13.0  57.0
# 39  90.0  68.0  90.0
# 40  36.0   NaN   4.0
# 41  55.0  75.0  26.0
# 42  77.0  99.0  43.0
# 43  45.0   NaN  65.0
# 44  20.0  61.0  60.0
# 45  70.0   5.0  58.0
# 46   NaN  92.0   8.0
# 47   9.0  79.0   4.0
# 48   2.0  65.0   NaN
# 49  74.0  53.0   7.0

# %%
# PART A
print(dataframe.isnull().sum().sum())
# Out:
# 15

# %%
# PART B
nan_col=dataframe.columns[dataframe.isnull().any()]
nan_col

for col in nan_col:
    print(col,dataframe[col].isnull().sum())
# Out:
# 1 5
# 2 5
# 3 5

# %%
#PART C
# sum=dataframe.sum(axis=1)
# print("SUM IS ::-->\n",sum)
# print("\n MAXIMUM SUM IS ::--> ",sum.max())
# print("\n row no. having maiximum sum is ::" ,dataframe.sum(axis=1).idxmax())
# -------------------------------------------
# sum=dataframe.sum(axis=1)
# print("SUM IS ::-->\n",sum)
# print("\n MAXIMUM SUM IS ::--> ",sum.max())
# max_sum_row = dataframe.sum(axis=1).idxmax()
# print("\n row no. having maiximum sum is ::" ,max_sum_row)

# dataframe=dataframe.drop(labels =45 ,axis =0)
# dataframe
# --------------------------------------

# %%
#PART C
sum=dataframe.sum(axis=1)
print("SUM IS ::-->\n",sum)
print("\n MAXIMUM SUM IS ::--> ",sum.max())
max_sum_row = dataframe.sum(axis=1).idxmax()
print("\n row no. having maiximum sum is ::" ,max_sum_row)

dataframe=dataframe.drop(max_sum_row ,axis =0)
print("\n DATA AFTER REMOVING THE ROW HAVING MAXIMUM VALUE")
dataframe
# Out:
# SUM IS ::-->
#  0     188.0
# 1      57.0
# 2     132.0
# 3     133.0
# 4      77.0
# 5      99.0
# 6     145.0
# 7     232.0
# 8     110.0
# 9     119.0
# 10    141.0
# 11    216.0
# 12    125.0
# 13    160.0
# 14    142.0
# 15    147.0
# 16     50.0
# 17    148.0
# 18    140.0
# 19    230.0
# 20    214.0
# 21    185.0
# 22    202.0
# 23    126.0
# 24    224.0
# 25     70.0
# 26    229.0
# 27    163.0
# 28     76.0
# 29     81.0
# 30    201.0
# 31    176.0
# 32    126.0
# 33     65.0
# 34    120.0
# 35     96.0
# 36    220.0
# 37    171.0
# 38    120.0
# 39    248.0
# 40     40.0
# 41    156.0
# 42    219.0
# 43    110.0
# 44    141.0
# 45    133.0
# 46    100.0
# 47     92.0
# 48     67.0
# 49    134.0
# dtype: float64
#
#  MAXIMUM SUM IS ::-->  248.0
#
#  row no. having maiximum sum is :: 39
#
#  DATA AFTER REMOVING THE ROW HAVING MAXIMUM VALUE
#        1     2     3
# 0   96.0  54.0  38.0
# 1   53.0   0.0   4.0
# 2    NaN  96.0  36.0
# 3   48.0  84.0   1.0
# 4    NaN   NaN  77.0
# 5   87.0  12.0   NaN
# 6   98.0   3.0  44.0
# 7   85.0  90.0  57.0
# 8    NaN  62.0  48.0
# 9    NaN  95.0  24.0
# 10  15.0  75.0  51.0
# 11  91.0  60.0  65.0
# 12  35.0  55.0  35.0
# 13  33.0  59.0  68.0
# 14  39.0  54.0  49.0
# 15  49.0  39.0  59.0
# 16  28.0  22.0   NaN
# 17  69.0   NaN  79.0
# 18  67.0  56.0  17.0
# 19  79.0  88.0  63.0
# 20  91.0  45.0  78.0
# 21  48.0  52.0  85.0
# 22  28.0  83.0  91.0
# 23  18.0  65.0  43.0
# 24  93.0  39.0  92.0
# 25  52.0  18.0   NaN
# 26  78.0  67.0  84.0
# 27  52.0  33.0  78.0
# 28  43.0   2.0  31.0
# 29  54.0  25.0   2.0
# 30  98.0  64.0  39.0
# 31  35.0  78.0  63.0
# 32  69.0  19.0  38.0
# 33  42.0   NaN  23.0
# 34  54.0  66.0   NaN
# 35  55.0  10.0  31.0
# 36  53.0  85.0  82.0
# 37   4.0  70.0  97.0
# 38  50.0  13.0  57.0
# 40  36.0   NaN   4.0
# 41  55.0  75.0  26.0
# 42  77.0  99.0  43.0
# 43  45.0   NaN  65.0
# 44  20.0  61.0  60.0
# 45  70.0   5.0  58.0
# 46   NaN  92.0   8.0
# 47   9.0  79.0   4.0
# 48   2.0  65.0   NaN
# 49  74.0  53.0   7.0

# %%
# PART D
sortdf=dataframe.sort_values('1')
sortdf
# Out:
#        1     2     3
# 48   2.0  65.0   NaN
# 37   4.0  70.0  97.0
# 47   9.0  79.0   4.0
# 10  15.0  75.0  51.0
# 23  18.0  65.0  43.0
# 44  20.0  61.0  60.0
# 16  28.0  22.0   NaN
# 22  28.0  83.0  91.0
# 13  33.0  59.0  68.0
# 12  35.0  55.0  35.0
# 31  35.0  78.0  63.0
# 40  36.0   NaN   4.0
# 14  39.0  54.0  49.0
# 33  42.0   NaN  23.0
# 28  43.0   2.0  31.0
# 43  45.0   NaN  65.0
# 3   48.0  84.0   1.0
# 21  48.0  52.0  85.0
# 15  49.0  39.0  59.0
# 38  50.0  13.0  57.0
# 27  52.0  33.0  78.0
# 25  52.0  18.0   NaN
# 36  53.0  85.0  82.0
# 1   53.0   0.0   4.0
# 34  54.0  66.0   NaN
# 29  54.0  25.0   2.0
# 41  55.0  75.0  26.0
# 35  55.0  10.0  31.0
# 18  67.0  56.0  17.0
# 17  69.0   NaN  79.0
# 32  69.0  19.0  38.0
# 45  70.0   5.0  58.0
# 49  74.0  53.0   7.0
# 42  77.0  99.0  43.0
# 26  78.0  67.0  84.0
# 19  79.0  88.0  63.0
# 7   85.0  90.0  57.0
# 5   87.0  12.0   NaN
# 20  91.0  45.0  78.0
# 11  91.0  60.0  65.0
# 24  93.0  39.0  92.0
# 0   96.0  54.0  38.0
# 6   98.0   3.0  44.0
# 30  98.0  64.0  39.0
# 2    NaN  96.0  36.0
# 4    NaN   NaN  77.0
# 8    NaN  62.0  48.0
# 9    NaN  95.0  24.0
# 46   NaN  92.0   8.0

# %%
# PART E
dataframe =dataframe.drop_duplicates(subset='1',keep = "first")
print(dataframe)
# Out:
#        1     2     3
# 0   96.0  54.0  38.0
# 1   53.0   0.0   4.0
# 2    NaN  96.0  36.0
# 3   48.0  84.0   1.0
# 5   87.0  12.0   NaN
# 6   98.0   3.0  44.0
# 7   85.0  90.0  57.0
# 10  15.0  75.0  51.0
# 11  91.0  60.0  65.0
# 12  35.0  55.0  35.0
# 13  33.0  59.0  68.0
# 14  39.0  54.0  49.0
# 15  49.0  39.0  59.0
# 16  28.0  22.0   NaN
# 17  69.0   NaN  79.0
# 18  67.0  56.0  17.0
# 19  79.0  88.0  63.0
# 23  18.0  65.0  43.0
# 24  93.0  39.0  92.0
# 25  52.0  18.0   NaN
# 26  78.0  67.0  84.0
# 28  43.0   2.0  31.0
# 29  54.0  25.0   2.0
# 33  42.0   NaN  23.0
# 35  55.0  10.0  31.0
# 37   4.0  70.0  97.0
# 38  50.0  13.0  57.0
# 40  36.0   NaN   4.0
# 42  77.0  99.0  43.0
# 43  45.0   NaN  65.0
# 44  20.0  61.0  60.0
# 45  70.0   5.0  58.0
# 47   9.0  79.0   4.0
# 48   2.0  65.0   NaN
# 49  74.0  53.0   7.0

# %%
# output
# ii remove

# %%
# PART F
correlation = dataframe['1'].corr(dataframe['2'])
print("CORRELATION IS :: ", correlation)
covariance = dataframe['2'].cov(dataframe['3'])
print("COVARIANCE IS :: ",covariance)
# Out:
# CORRELATION IS ::  -0.1648552582557222
# COVARIANCE IS ::  106.07264957264955

# %%
#PART G
import seaborn as sns
sns.boxplot(x=dataframe['3'])
# Out:
# <AxesSubplot:xlabel='3'>

# %%
# PART H
dataframe =  pd.cut(dataframe['2'],bins=5).head()
dataframe
# Out:
# 0      (39.6, 59.4]
# 1    (-0.099, 19.8]
# 2      (79.2, 99.0]
# 3      (79.2, 99.0]
# 5    (-0.099, 19.8]
# Name: 2, dtype: category
# Categories (5, interval[float64, right]): [(-0.099, 19.8] < (19.8, 39.6] < (39.6, 59.4] < (59.4, 79.2] < (79.2, 99.0]]
