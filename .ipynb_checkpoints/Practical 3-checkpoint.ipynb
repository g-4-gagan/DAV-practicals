# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(50,3)), columns=list('123'))
df.head()
# Out:
#     1   2   3
# 0  14   8  99
# 1  51  16  62
# 2  99  59  33
# 3  49  84   7
# 4  87  94   2

# %%
for c in  df.sample(int(df.shape[0]*df.shape[1]*0.10)).index:
    df.loc[c,str(np.random.randint(1,4))]=np.nan
df
# Out:
#        1     2     3
# 0   14.0   8.0  99.0
# 1   51.0  16.0  62.0
# 2   99.0  59.0  33.0
# 3   49.0  84.0   NaN
# 4   87.0  94.0   2.0
# 5   99.0  64.0  83.0
# 6   51.0   4.0  32.0
# 7   33.0  93.0  30.0
# 8   18.0  29.0  35.0
# 9   64.0  74.0  67.0
# 10  71.0  23.0  19.0
# 11   0.0  91.0  65.0
# 12  81.0  52.0  30.0
# 13  58.0  15.0   NaN
# 14   NaN   9.0  66.0
# 15   4.0  87.0  28.0
# 16  60.0   NaN  39.0
# 17   5.0  18.0  33.0
# 18  60.0  77.0  47.0
# 19  26.0  72.0   5.0
# 20  41.0  71.0  42.0
# 21  14.0  51.0  51.0
# 22  71.0  72.0  66.0
# 23  89.0  52.0  79.0
# 24  12.0  84.0  62.0
# 25  78.0  13.0  94.0
# 26  17.0  28.0  30.0
# 27  35.0  36.0  31.0
# 28  76.0   NaN  79.0
# 29  94.0  82.0  74.0
# 30  18.0  30.0  29.0
# 31  88.0  65.0  88.0
# 32  45.0  37.0  39.0
# 33  43.0  24.0  30.0
# 34  95.0  82.0  25.0
# 35   NaN  33.0  86.0
# 36   NaN  91.0  62.0
# 37  25.0  26.0   NaN
# 38   1.0   NaN  29.0
# 39  48.0  93.0  68.0
# 40   0.0   NaN   2.0
# 41  32.0  95.0  34.0
# 42  86.0   NaN   5.0
# 43  66.0  81.0  75.0
# 44  49.0   NaN  21.0
# 45   8.0   NaN  60.0
# 46  36.0   0.0  22.0
# 47   7.0  63.0  15.0
# 48  84.0  54.0   NaN
# 49  42.0  98.0   NaN

# %%
#part A
print(df.isnull().sum().sum())
# Out:
# 15

# %%
for col in df.columns:
    print(col,df[col].isnull().sum())
df.dropna(axis = 1,thresh=(df.shape[0]-5)).head()
# Out:
# 1 3
# 2 7
# 3 5
#       1     3
# 0  14.0  99.0
# 1  51.0  62.0
# 2  99.0  33.0
# 3  49.0   NaN
# 4  87.0   2.0

# %%
sum=df.sum(axis=1)
print("SUM IS :\n",sum)
print("\nMAXIMUM SUM IS :",sum.max())
max_sum_row = df.sum(axis=1).idxmax()
print("\nRow index having maximum sum is :" ,max_sum_row)

df = df.drop(max_sum_row ,axis =0)
print("\nDATA Frame AFTER REMOVING THE ROW HAVING MAXIMUM SUM VALUE")
df
# Out:
# SUM IS :
#  0     121.0
# 1     129.0
# 2     191.0
# 3     133.0
# 4     183.0
# 5     246.0
# 6      87.0
# 7     156.0
# 8      82.0
# 9     205.0
# 10    113.0
# 11    156.0
# 12    163.0
# 13     73.0
# 14     75.0
# 15    119.0
# 16     99.0
# 17     56.0
# 18    184.0
# 19    103.0
# 20    154.0
# 21    116.0
# 22    209.0
# 23    220.0
# 24    158.0
# 25    185.0
# 26     75.0
# 27    102.0
# 28    155.0
# 29    250.0
# 30     77.0
# 31    241.0
# 32    121.0
# 33     97.0
# 34    202.0
# 35    119.0
# 36    153.0
# 37     51.0
# 38     30.0
# 39    209.0
# 40      2.0
# 41    161.0
# 42     91.0
# 43    222.0
# 44     70.0
# 45     68.0
# 46     58.0
# 47     85.0
# 48    138.0
# 49    140.0
# dtype: float64
#
# MAXIMUM SUM IS : 250.0
#
# Row index having maximum sum is : 29
#
# DATA Frame AFTER REMOVING THE ROW HAVING MAXIMUM SUM VALUE
#        1     2     3
# 0   14.0   8.0  99.0
# 1   51.0  16.0  62.0
# 2   99.0  59.0  33.0
# 3   49.0  84.0   NaN
# 4   87.0  94.0   2.0
# 5   99.0  64.0  83.0
# 6   51.0   4.0  32.0
# 7   33.0  93.0  30.0
# 8   18.0  29.0  35.0
# 9   64.0  74.0  67.0
# 10  71.0  23.0  19.0
# 11   0.0  91.0  65.0
# 12  81.0  52.0  30.0
# 13  58.0  15.0   NaN
# 14   NaN   9.0  66.0
# 15   4.0  87.0  28.0
# 16  60.0   NaN  39.0
# 17   5.0  18.0  33.0
# 18  60.0  77.0  47.0
# 19  26.0  72.0   5.0
# 20  41.0  71.0  42.0
# 21  14.0  51.0  51.0
# 22  71.0  72.0  66.0
# 23  89.0  52.0  79.0
# 24  12.0  84.0  62.0
# 25  78.0  13.0  94.0
# 26  17.0  28.0  30.0
# 27  35.0  36.0  31.0
# 28  76.0   NaN  79.0
# 30  18.0  30.0  29.0
# 31  88.0  65.0  88.0
# 32  45.0  37.0  39.0
# 33  43.0  24.0  30.0
# 34  95.0  82.0  25.0
# 35   NaN  33.0  86.0
# 36   NaN  91.0  62.0
# 37  25.0  26.0   NaN
# 38   1.0   NaN  29.0
# 39  48.0  93.0  68.0
# 40   0.0   NaN   2.0
# 41  32.0  95.0  34.0
# 42  86.0   NaN   5.0
# 43  66.0  81.0  75.0
# 44  49.0   NaN  21.0
# 45   8.0   NaN  60.0
# 46  36.0   0.0  22.0
# 47   7.0  63.0  15.0
# 48  84.0  54.0   NaN
# 49  42.0  98.0   NaN

# %%
#part D
sortdf=df.sort_values('1')
sortdf.head()
# Out:
#       1     2     3
# 40  0.0   NaN   2.0
# 11  0.0  91.0  65.0
# 38  1.0   NaN  29.0
# 15  4.0  87.0  28.0
# 17  5.0  18.0  33.0

# %%
# PART E
df =df.drop_duplicates(subset='1',keep = "first")
print(df)
# Out:
#        1     2     3
# 0   14.0   8.0  99.0
# 1   51.0  16.0  62.0
# 2   99.0  59.0  33.0
# 3   49.0  84.0   NaN
# 4   87.0  94.0   2.0
# 7   33.0  93.0  30.0
# 8   18.0  29.0  35.0
# 9   64.0  74.0  67.0
# 10  71.0  23.0  19.0
# 11   0.0  91.0  65.0
# 12  81.0  52.0  30.0
# 13  58.0  15.0   NaN
# 14   NaN   9.0  66.0
# 15   4.0  87.0  28.0
# 16  60.0   NaN  39.0
# 17   5.0  18.0  33.0
# 19  26.0  72.0   5.0
# 20  41.0  71.0  42.0
# 23  89.0  52.0  79.0
# 24  12.0  84.0  62.0
# 25  78.0  13.0  94.0
# 26  17.0  28.0  30.0
# 27  35.0  36.0  31.0
# 28  76.0   NaN  79.0
# 31  88.0  65.0  88.0
# 32  45.0  37.0  39.0
# 33  43.0  24.0  30.0
# 34  95.0  82.0  25.0
# 37  25.0  26.0   NaN
# 38   1.0   NaN  29.0
# 39  48.0  93.0  68.0
# 41  32.0  95.0  34.0
# 42  86.0   NaN   5.0
# 43  66.0  81.0  75.0
# 45   8.0   NaN  60.0
# 46  36.0   0.0  22.0
# 47   7.0  63.0  15.0
# 48  84.0  54.0   NaN
# 49  42.0  98.0   NaN

# %%
#part F
correlation = df['1'].corr(df['2'])
print("CORRELATION between column 1 and 2 : ", correlation)
covariance = df['2'].cov(df['3'])
print("COVARIANCE between column 2 and 3 :",covariance)
# Out:
# CORRELATION between column 1 and 2 :  0.05285222629744526
# COVARIANCE between column 2 and 3 : -118.00862068965519

# %%
#part G
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
#part H
df1 =  pd.cut(df['2'],bins=5).head()
df1
# Out:
# 0    (-0.098, 19.6]
# 1    (-0.098, 19.6]
# 2      (58.8, 78.4]
# 3      (78.4, 98.0]
# 4      (78.4, 98.0]
# Name: 2, dtype: category
# Categories (5, interval[float64, right]): [(-0.098, 19.6] < (19.6, 39.2] < (39.2, 58.8] < (58.8, 78.4] < (78.4, 98.0]]
